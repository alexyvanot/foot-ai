# %% [markdown]
# # FootAI

# %%
# Import libraries
import numpy as np
import pandas as pd

import cv2
import skimage
from PIL import Image
from ultralytics import YOLO
from sklearn.metrics import mean_squared_error

import json
import yaml
import time
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\alexy\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Get tactical map keypoints positions dictionary
json_path = "./pitch map labels position.json"
with open(json_path, 'r') as f:
    keypoints_map_pos = json.load(f)

# Get football field keypoints numerical to alphabetical mapping
yaml_path = "./config pitch dataset.yaml"
with open(yaml_path, 'r') as file:
    classes_names_dic = yaml.safe_load(file)
classes_names_dic = classes_names_dic['names']

# Get football field keypoints numerical to alphabetical mapping
yaml_path = "./config players dataset.yaml"
with open(yaml_path, 'r') as file:
    labels_dic = yaml.safe_load(file)
labels_dic = labels_dic['names']

print("Known coordinates of each keypoint on the tactical map:")
display(pd.DataFrame(keypoints_map_pos, index=['x','y']))
print("Numerical label of field keypoints (as defined when training the Yolo model):")
display(pd.Series(classes_names_dic, name='alpha_label').reset_index().rename({"index":"num_label"}, axis=1).set_index("alpha_label").transpose())
print("Numerical label of the player, referee, and ball objects (as defined when training the Yolo model):")
display(pd.Series(labels_dic, name='alpha_label').reset_index().rename({"index":"num_label"}, axis=1).set_index("alpha_label").transpose())
print('\033[1mThe dataframe representation are not used in what follows (original dictionary will be used)')
# Out:
# Known coordinates of each keypoint on the tactical map:
#    TLC  TRC  TR6MC  TL6MC  TR6ML  TL6ML  TR18MC  TL18MC  TR18ML  TL18ML  ...  \
# x   15  291    188    116    189    116     221      84     221      84  ...
# y   15   15     35     35     15     15      73      73      15      15  ...
#
#    BR6MC  BL6MC  BR6ML  BL6ML  BR18MC  BL18MC  BR18ML  BL18ML  BRArc  BLArc
# x    189    117    189    117     221      84     221      84    182    121
# y    501    501    521    521     463     463     521     521    463    463
#
# [2 rows x 28 columns]
# Numerical label of field keypoints (as defined when training the Yolo model):
# alpha_label  TLC  TRC  TR6MC  TL6MC  TR6ML  TL6ML  TR18MC  TL18MC  TR18ML  \
# num_label      0    1      2      3      4      5       6       7       8
#
# alpha_label  TL18ML  ...  BR6MC  BL6MC  BR6ML  BL6ML  BR18MC  BL18MC  BR18ML  \
# num_label         9  ...     18     19     20     21      22      23      24
#
# alpha_label  BL18ML  BRArc  BLArc
# num_label        25     26     27
#
# [1 rows x 28 columns]
# Numerical label of the player, referee, and ball objects (as defined when training the Yolo model):
# alpha_label  player  referee  ball
# num_label         0        1     2
# The dataframe representation are not used in what follows (original dictionary will be used)

# %%
# Set video path
video_path = './test vid.mp4'

# Read tactical map image
tac_map = cv2.imread('./tactical map.jpg')

# Define team colors (based on chosen video)
nbr_team_colors = 2
colors_dic = {
    "Chelsea":[(41,71,138), (220,98,88)], # Chelsea colors (Players kit color, GK kit color)
    "Man City":[(144,200,255), (188,199,3)] # Man City colors (Players kit color, GK kit color)
}

colors_list = colors_dic["Chelsea"]+colors_dic["Man City"] # Define color list to be used for detected player team prediction
color_list_lab = [skimage.color.rgb2lab([i/255 for i in c]) for c in colors_list] # Converting color_list to L*a*b* space

# %%
# Load the YOLOv8 players detection model
model_players = YOLO("./models/Yolo8L Players/weights/best.pt")

# Load the YOLOv8 field keypoints detection model
model_keypoints = YOLO("./models/Yolo8M Field Keypoints/weights/best.pt")

# %%
# Open video file
cap = cv2.VideoCapture(video_path)

# Initialize frame counter
frame_nbr = 0

# Set keypoints average displacement tolerance level (in pixels) [set to -1 to always update homography matrix]
keypoints_displacement_mean_tol = 10

# Set confidence thresholds for players and field keypoints detections
player_model_conf_thresh = 0.60
keypoints_model_conf_thresh = 0.70

# Set variable to record the time when we processed last frame 
prev_frame_time = 0
# Set variable to record the time at which we processed current frame 
new_frame_time = 0

# Store the ball track history
ball_track_history = {'src':[],
                      'dst':[]
}

# Count consecutive frames with no ball detected
nbr_frames_no_ball = 0
# Threshold for number of frames with no ball to reset ball track (frames)
nbr_frames_no_ball_thresh = 30
# Distance threshold for ball tracking (pixels)
ball_track_dist_thresh = 100
# Maximum ball track length (detections)
max_track_length = 35

# Loop through the video frames
while cap.isOpened():

    # Update frame counter
    frame_nbr += 1

    # Read a frame from the video
    success, frame = cap.read()

    # Reset tactical map image for each new frame
    tac_map_copy = tac_map.copy()

    # Reset ball tracks
    if nbr_frames_no_ball>nbr_frames_no_ball_thresh:
            ball_track_history['dst'] = []
            ball_track_history['src'] = []

    # Process the frame if it was successfuly read
    if success:
        
        #################### Part 1 ####################
        # Object Detection & Coordiante Transofrmation #
        ################################################

        # Run YOLOv8 players inference on the frame
        results_players = model_players(frame, conf=player_model_conf_thresh)
        # Run YOLOv8 field keypoints inference on the frame
        results_keypoints = model_keypoints(frame, conf=keypoints_model_conf_thresh)

        ## Extract detections information
        bboxes_p = results_players[0].boxes.xyxy.cpu().numpy()                          # Detected players, referees and ball (x,y,x,y) bounding boxes
        bboxes_p_c = results_players[0].boxes.xywh.cpu().numpy()                        # Detected players, referees and ball (x,y,w,h) bounding boxes    
        labels_p = list(results_players[0].boxes.cls.cpu().numpy())                     # Detected players, referees and ball labels list
        confs_p = list(results_players[0].boxes.conf.cpu().numpy())                     # Detected players, referees and ball confidence level
        
        bboxes_k = results_keypoints[0].boxes.xyxy.cpu().numpy()                        # Detected field keypoints (x,y,w,h) bounding boxes
        bboxes_k_c = results_keypoints[0].boxes.xywh.cpu().numpy()                        # Detected field keypoints (x,y,w,h) bounding boxes
        labels_k = list(results_keypoints[0].boxes.cls.cpu().numpy())                   # Detected field keypoints labels list

        # Convert detected numerical labels to alphabetical labels
        detected_labels = [classes_names_dic[i] for i in labels_k]

        # Extract detected field keypoints coordiantes on the current frame
        detected_labels_src_pts = np.array([list(np.round(bboxes_k_c[i][:2]).astype(int)) for i in range(bboxes_k_c.shape[0])])

        # Get the detected field keypoints coordinates on the tactical map
        detected_labels_dst_pts = np.array([keypoints_map_pos[i] for i in detected_labels])


        ## Calculate Homography transformation matrix when more than 4 keypoints are detected
        if len(detected_labels) > 3:
            # Always calculate homography matrix on the first frame
            if frame_nbr > 1:
                # Determine common detected field keypoints between previous and current frames
                common_labels = set(detected_labels_prev) & set(detected_labels)
                # When at least 4 common keypoints are detected, determine if they are displaced on average beyond a certain tolerance level
                if len(common_labels) > 3:
                    common_label_idx_prev = [detected_labels_prev.index(i) for i in common_labels]   # Get labels indexes of common detected keypoints from previous frame
                    common_label_idx_curr = [detected_labels.index(i) for i in common_labels]        # Get labels indexes of common detected keypoints from current frame
                    coor_common_label_prev = detected_labels_src_pts_prev[common_label_idx_prev]     # Get labels coordiantes of common detected keypoints from previous frame
                    coor_common_label_curr = detected_labels_src_pts[common_label_idx_curr]          # Get labels coordiantes of common detected keypoints from current frame
                    coor_error = mean_squared_error(coor_common_label_prev, coor_common_label_curr)  # Calculate error between previous and current common keypoints coordinates
                    update_homography = coor_error > keypoints_displacement_mean_tol                 # Check if error surpassed the predefined tolerance level
                else:
                    update_homography = True                                                         
            else:
                update_homography = True

            if  update_homography:
                h, mask = cv2.findHomography(detected_labels_src_pts,                   # Calculate homography matrix
                                              detected_labels_dst_pts)                  
            
            detected_labels_prev = detected_labels.copy()                               # Save current detected keypoint labels for next frame
            detected_labels_src_pts_prev = detected_labels_src_pts.copy()               # Save current detected keypoint coordiantes for next frame

            bboxes_p_c_0 = bboxes_p_c[[i==0 for i in labels_p],:]                       # Get bounding boxes information (x,y,w,h) of detected players (label 0)
            bboxes_p_c_2 = bboxes_p_c[[i==2 for i in labels_p],:]                       # Get bounding boxes information (x,y,w,h) of detected ball(s) (label 2)

            # Get coordinates of detected players on frame (x_cencter, y_center+h/2)
            detected_ppos_src_pts = bboxes_p_c_0[:,:2]  + np.array([[0]*bboxes_p_c_0.shape[0], bboxes_p_c_0[:,3]/2]).transpose()
            # Get coordinates of the first detected ball (x_center, y_center)
            detected_ball_src_pos = bboxes_p_c_2[0,:2] if bboxes_p_c_2.shape[0]>0 else None

            # Transform players coordinates from frame plane to tactical map plance using the calculated Homography matrix
            pred_dst_pts = []                                                           # Initialize players tactical map coordiantes list
            for pt in detected_ppos_src_pts:                                            # Loop over players frame coordiantes
                pt = np.append(np.array(pt), np.array([1]), axis=0)                     # Covert to homogeneous coordiantes
                dest_point = np.matmul(h, np.transpose(pt))                              # Apply homography transofrmation
                dest_point = dest_point/dest_point[2]                                   # Revert to 2D-coordiantes
                pred_dst_pts.append(list(np.transpose(dest_point)[:2]))                 # Update players tactical map coordiantes list
            pred_dst_pts = np.array(pred_dst_pts)

            # Transform ball coordinates from frame plane to tactical map plane using the calculated Homography matrix
            if detected_ball_src_pos is not None:
                pt = np.append(np.array(detected_ball_src_pos), np.array([1]), axis=0)
                dest_point = np.matmul(h, np.transpose(pt))
                dest_point = dest_point/dest_point[2]
                detected_ball_dst_pos = np.transpose(dest_point)

                # Update track ball position history
                if len(ball_track_history['src'])>0 :
                    if np.linalg.norm(detected_ball_src_pos-ball_track_history['src'][-1])<ball_track_dist_thresh:
                        ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                        ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
                    else:
                        ball_track_history['src']=[(int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1]))]
                        ball_track_history['dst']=[(int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1]))]
                else:
                    ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                    ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
            # Remove oldest tracked ball postion if track exceedes threshold        
            if len(ball_track_history) > max_track_length:
                    ball_track_history['src'].pop(0)
                    ball_track_history['dst'].pop(0)

        ######### Part 2 ########## 
        # Players Team Prediction #
        ###########################

        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)                                      # Convert frame to RGB
        obj_palette_list = []                                                                   # Initialize players color palette list
        palette_interval = (0,5)                                                                # Color interval to extract from dominant colors palette (1rd to 5th color)
        annotated_frame = frame                                                                 # Create annotated frame 

        ## Loop over detected players (label 0) and extract dominant colors palette based on defined interval
        for i, j in enumerate(list(results_players[0].boxes.cls.cpu().numpy())):
            if int(j) == 0:
                bbox = results_players[0].boxes.xyxy.cpu().numpy()[i,:]                         # Get bbox info (x,y,x,y)
                obj_img = frame_rgb[int(bbox[1]):int(bbox[3]), int(bbox[0]):int(bbox[2])]       # Crop bbox out of the frame
                obj_img_w, obj_img_h = obj_img.shape[1], obj_img.shape[0]
                center_filter_x1 = np.max([(obj_img_w//2)-(obj_img_w//5), 1])
                center_filter_x2 = (obj_img_w//2)+(obj_img_w//5)
                center_filter_y1 = np.max([(obj_img_h//3)-(obj_img_h//5), 1])
                center_filter_y2 = (obj_img_h//3)+(obj_img_h//5)
                center_filter = obj_img[center_filter_y1:center_filter_y2, 
                                        center_filter_x1:center_filter_x2]
                obj_pil_img = Image.fromarray(np.uint8(center_filter))                          # Convert to pillow image
                    
                reduced = obj_pil_img.convert("P", palette=Image.Palette.WEB)                   # Convert to web palette (216 colors)
                palette = reduced.getpalette()                                                  # Get palette as [r,g,b,r,g,b,...]
                palette = [palette[3*n:3*n+3] for n in range(256)]                              # Group 3 by 3 = [[r,g,b],[r,g,b],...]
                color_count = [(n, palette[m]) for n,m in reduced.getcolors()]                  # Create list of palette colors with their frequency
                RGB_df = pd.DataFrame(color_count, columns = ['cnt', 'RGB']).sort_values(       # Create dataframe based on defined palette interval
                                      by = 'cnt', ascending = False).iloc[
                                          palette_interval[0]:palette_interval[1],:]
                palette = list(RGB_df.RGB)                                                      # Convert palette to list (for faster processing)
                annotated_frame = cv2.rectangle(annotated_frame,                                # Add center filter bbox annotations
                                                (int(bbox[0])+center_filter_x1, 
                                                 int(bbox[1])+ center_filter_y1),  
                                                (int(bbox[0])+center_filter_x2, 
                                                 int(bbox[1])+center_filter_y2), (0,0,0), 2)
                
                # Update detected players color palette list
                obj_palette_list.append(palette)
        
        ## Calculate distances between each color from every detected player color palette and the predefined teams colors
        players_distance_features = []
        # Loop over detected players extracted color palettes
        for palette in obj_palette_list:
            palette_distance = []
            palette_lab = [skimage.color.rgb2lab([i/255 for i in color]) for color in palette]  # Convert colors to L*a*b* space
            # Loop over colors in palette
            for color in palette_lab:
                distance_list = []
                # Loop over predefined list of teams colors
                for c in color_list_lab:
                    #distance = np.linalg.norm([i/255 - j/255 for i,j in zip(color,c)])
                    distance = skimage.color.deltaE_cie76(color, c)                             # Calculate Euclidean distance in Lab color space
                    distance_list.append(distance)                                              # Update distance list for current color
                palette_distance.append(distance_list)                                          # Update distance list for current palette
            players_distance_features.append(palette_distance)                                  # Update distance features list

        ## Predict detected players teams based on distance features
        players_teams_list = []
        # Loop over players distance features
        for distance_feats in players_distance_features:
            vote_list=[]
            # Loop over distances for each color 
            for dist_list in distance_feats:
                team_idx = dist_list.index(min(dist_list))//nbr_team_colors                     # Assign team index for current color based on min distance
                vote_list.append(team_idx)                                                      # Update vote voting list with current color team prediction
            players_teams_list.append(max(vote_list, key=vote_list.count))                      # Predict current player team by vote counting


        #################### Part 3 #####################
        # Updated Frame & Tactical Map With Annotations #
        #################################################

        ball_color_bgr = (0,0,255)                                                                          # Color (GBR) for ball annotation on tactical map
        j=0                                                                                                 # Initializing counter of detected players
        palette_box_size = 10                                                                               # Set color box size in pixels (for display)
        

        # Loop over all detected object by players detection model
        for i in range(bboxes_p.shape[0]):
            conf = confs_p[i]                                                                               # Get confidence of current detected object
            if labels_p[i]==0:                                                                              # Display annotation for detected players (label 0)
                
                # Display extracted color palette for each detected player
                palette = obj_palette_list[j]                                                               # Get color palette of the detected player
                for k, c in enumerate(palette):
                    c_bgr = c[::-1]                                                                         # Convert color to BGR
                    annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,2])+3,                 # Add color palette annotation on frame
                                                            int(bboxes_p[i,1])+k*palette_box_size),
                                                            (int(bboxes_p[i,2])+palette_box_size,
                                                            int(bboxes_p[i,1])+(palette_box_size)*(k+1)),
                                                              c_bgr, -1)

                team_name = list(colors_dic.keys())[players_teams_list[j]]                                  # Get detected player team prediction
                color_rgb = colors_dic[team_name][0]                                                        # Get detected player team color
                color_bgr = color_rgb[::-1]                                                                 # Convert color to bgr

                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  # Add bbox annotations with team colors
                                                (int(bboxes_p[i,2]), int(bboxes_p[i,3])), color_bgr, 1)
                
                cv2.putText(annotated_frame, team_name + f" {conf:.2f}",                                    # Add team name annotations
                             (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                               color_bgr, 2)
                
                # Add tactical map player postion color coded annotation if more than 3 field keypoints are detected
                if len(detected_labels_src_pts)>3:
                    tac_map_copy = cv2.circle(tac_map_copy, (int(pred_dst_pts[j][0]),int(pred_dst_pts[j][1])),
                                          radius=5, color=color_bgr, thickness=-1)

                j+=1                                                                                        # Update players counter
            else:                                                                                           # Display annotation for otehr detections (label 1, 2)
                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  # Add white colored bbox annotations
                                                 (int(bboxes_p[i,2]), int(bboxes_p[i,3])), (255,255,255), 1)
                cv2.putText(annotated_frame, labels_dic[labels_p[i]] + f" {conf:.2f}",                      # Add white colored label text annotations
                            (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                              (255,255,255), 2)

                # Add tactical map ball postion annotation if detected
                if detected_ball_src_pos is not None:
                    tac_map_copy = cv2.circle(tac_map_copy, (int(detected_ball_dst_pos[0]), 
                                                   int(detected_ball_dst_pos[1])), radius=5, 
                                                   color=ball_color_bgr, thickness=3)
        for i in range(bboxes_k.shape[0]):
            annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_k[i,0]), int(bboxes_k[i,1])),  # Add bbox annotations with team colors
                                        (int(bboxes_k[i,2]), int(bboxes_k[i,3])), (0,0,0), 1)
        
        # Plot the ball tracks on tactical map
        if len(ball_track_history['src'])>0:
            points = np.hstack(ball_track_history['dst']).astype(np.int32).reshape((-1, 1, 2))
            tac_map_copy = cv2.polylines(tac_map_copy, [points], isClosed=False, color=(0, 0, 100), thickness=2)
        
        # Combine annotated frame and tactical map in one image with colored border separation
        border_color = [255,255,255]                                                                        # Set border color (BGR)
        annotated_frame=cv2.copyMakeBorder(annotated_frame, 40, 10, 10, 10,                                 # Add borders to annotated frame
                                            cv2.BORDER_CONSTANT, value=border_color)
        tac_map_copy = cv2.copyMakeBorder(tac_map_copy, 70, 50, 10, 10, cv2.BORDER_CONSTANT,                # Add borders to tactical map 
                                           value=border_color)      
        tac_map_copy = cv2.resize(tac_map_copy, (tac_map_copy.shape[1], annotated_frame.shape[0]))          # Resize tactical map
        final_img = cv2.hconcat((annotated_frame, tac_map_copy))                                            # Concatenate both images
        ## Add info annotation
        cv2.putText(final_img, "Tactical Map", (1370,60), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
        cv2.putText(final_img, "Press 'p' to pause & 'q' to quit", (820,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)

        new_frame_time = time.time()                                                                        # Get time after finished processing current frame
        fps = 1/(new_frame_time-prev_frame_time)                                                            # Calculate FPS as 1/(frame proceesing duration)
        prev_frame_time = new_frame_time                                                                    # Save current time to be used in next frame
        cv2.putText(final_img, "FPS: " + str(int(fps)), (20,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
        
        # Display the final annotated frame
        cv2.imshow("YOLOv8 Players and Field Keypoints Detection with Team Prediction and Tactical Map",    
                    final_img)

        # Treat keyboard user inputs ("p" for pause/unpause & "q" for quit)
        key = cv2.waitKey(1)
        # Break the loop if 'q' is pressed
        if key == ord("q"):
            break
        if key == ord('p'):
            cv2.waitKey(-1) #wait until any key is pressed
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 19 players, 1 referee, 1 ball, 792.3ms
# Speed: 15.6ms preprocess, 792.3ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 405.0ms
# Speed: 2.8ms preprocess, 405.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 684.4ms
# Speed: 3.0ms preprocess, 684.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 467.0ms
# Speed: 4.2ms preprocess, 467.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 676.9ms
# Speed: 2.3ms preprocess, 676.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 358.2ms
# Speed: 2.6ms preprocess, 358.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 1 ball, 851.3ms
# Speed: 2.7ms preprocess, 851.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 433.0ms
# Speed: 2.2ms preprocess, 433.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 668.7ms
# Speed: 2.3ms preprocess, 668.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 384.6ms
# Speed: 2.1ms preprocess, 384.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 727.9ms
# Speed: 2.4ms preprocess, 727.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 411.4ms
# Speed: 2.7ms preprocess, 411.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 664.7ms
# Speed: 2.2ms preprocess, 664.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 360.9ms
# Speed: 2.2ms preprocess, 360.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 680.0ms
# Speed: 2.1ms preprocess, 680.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 BL18MC, 394.1ms
# Speed: 3.5ms preprocess, 394.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 671.1ms
# Speed: 2.1ms preprocess, 671.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 356.1ms
# Speed: 2.0ms preprocess, 356.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 661.3ms
# Speed: 2.3ms preprocess, 661.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 392.0ms
# Speed: 2.4ms preprocess, 392.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 655.1ms
# Speed: 2.8ms preprocess, 655.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 352.5ms
# Speed: 2.2ms preprocess, 352.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 658.2ms
# Speed: 2.5ms preprocess, 658.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 624.1ms
# Speed: 3.4ms preprocess, 624.1ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 669.4ms
# Speed: 2.0ms preprocess, 669.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 355.9ms
# Speed: 2.7ms preprocess, 355.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 678.4ms
# Speed: 2.4ms preprocess, 678.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 369.7ms
# Speed: 2.0ms preprocess, 369.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 648.4ms
# Speed: 2.7ms preprocess, 648.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 349.3ms
# Speed: 2.2ms preprocess, 349.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 663.6ms
# Speed: 3.4ms preprocess, 663.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 396.0ms
# Speed: 2.4ms preprocess, 396.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 732.3ms
# Speed: 2.1ms preprocess, 732.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 351.6ms
# Speed: 2.2ms preprocess, 351.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 657.1ms
# Speed: 2.2ms preprocess, 657.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 397.3ms
# Speed: 2.2ms preprocess, 397.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 663.3ms
# Speed: 2.1ms preprocess, 663.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 344.6ms
# Speed: 1.9ms preprocess, 344.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 677.1ms
# Speed: 2.3ms preprocess, 677.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 443.0ms
# Speed: 2.4ms preprocess, 443.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 673.0ms
# Speed: 2.3ms preprocess, 673.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 351.7ms
# Speed: 2.4ms preprocess, 351.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 657.7ms
# Speed: 2.1ms preprocess, 657.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 400.4ms
# Speed: 2.0ms preprocess, 400.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 670.3ms
# Speed: 1.9ms preprocess, 670.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 359.9ms
# Speed: 2.2ms preprocess, 359.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 672.5ms
# Speed: 2.1ms preprocess, 672.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 400.6ms
# Speed: 2.0ms preprocess, 400.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 665.8ms
# Speed: 4.0ms preprocess, 665.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 355.0ms
# Speed: 2.1ms preprocess, 355.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 655.3ms
# Speed: 2.3ms preprocess, 655.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 434.5ms
# Speed: 3.0ms preprocess, 434.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 664.4ms
# Speed: 4.4ms preprocess, 664.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 366.6ms
# Speed: 2.0ms preprocess, 366.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 1 ball, 655.1ms
# Speed: 3.0ms preprocess, 655.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 LMC, 1 BLArc, 599.7ms
# Speed: 2.1ms preprocess, 599.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 1 ball, 657.4ms
# Speed: 2.0ms preprocess, 657.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 LMC, 1 BL18MC, 1 BLArc, 357.6ms
# Speed: 2.0ms preprocess, 357.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 1 ball, 652.7ms
# Speed: 2.0ms preprocess, 652.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 LMC, 1 BL18MC, 1 BLArc, 412.9ms
# Speed: 2.0ms preprocess, 412.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 656.2ms
# Speed: 2.6ms preprocess, 656.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 351.4ms
# Speed: 2.1ms preprocess, 351.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 658.1ms
# Speed: 2.1ms preprocess, 658.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 430.8ms
# Speed: 1.9ms preprocess, 430.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 667.8ms
# Speed: 2.3ms preprocess, 667.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 353.6ms
# Speed: 2.1ms preprocess, 353.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 650.8ms
# Speed: 2.6ms preprocess, 650.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 375.2ms
# Speed: 2.2ms preprocess, 375.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 666.9ms
# Speed: 2.3ms preprocess, 666.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 351.2ms
# Speed: 2.2ms preprocess, 351.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 664.2ms
# Speed: 2.4ms preprocess, 664.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 375.5ms
# Speed: 2.5ms preprocess, 375.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 663.0ms
# Speed: 2.4ms preprocess, 663.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 347.2ms
# Speed: 2.7ms preprocess, 347.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 ball, 645.4ms
# Speed: 2.1ms preprocess, 645.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 354.7ms
# Speed: 2.0ms preprocess, 354.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 676.2ms
# Speed: 2.9ms preprocess, 676.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 361.1ms
# Speed: 3.0ms preprocess, 361.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 652.8ms
# Speed: 2.3ms preprocess, 652.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 352.1ms
# Speed: 2.0ms preprocess, 352.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 679.6ms
# Speed: 2.2ms preprocess, 679.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 346.9ms
# Speed: 2.0ms preprocess, 346.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 661.8ms
# Speed: 2.1ms preprocess, 661.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 349.0ms
# Speed: 2.0ms preprocess, 349.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 690.9ms
# Speed: 2.5ms preprocess, 690.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 344.1ms
# Speed: 2.3ms preprocess, 344.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 635.6ms
# Speed: 2.1ms preprocess, 635.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 348.2ms
# Speed: 2.0ms preprocess, 348.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 ball, 709.1ms
# Speed: 2.1ms preprocess, 709.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 355.2ms
# Speed: 2.0ms preprocess, 355.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 ball, 682.3ms
# Speed: 2.1ms preprocess, 682.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 360.1ms
# Speed: 2.0ms preprocess, 360.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 735.1ms
# Speed: 3.0ms preprocess, 735.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 504.6ms
# Speed: 2.2ms preprocess, 504.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 663.9ms
# Speed: 4.1ms preprocess, 663.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 358.2ms
# Speed: 2.6ms preprocess, 358.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 697.4ms
# Speed: 2.5ms preprocess, 697.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 359.0ms
# Speed: 2.2ms preprocess, 359.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 732.7ms
# Speed: 2.0ms preprocess, 732.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 357.1ms
# Speed: 2.1ms preprocess, 357.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 690.5ms
# Speed: 2.2ms preprocess, 690.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL18MC, 1 BLArc, 352.2ms
# Speed: 2.3ms preprocess, 352.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 672.0ms
# Speed: 2.0ms preprocess, 672.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 362.1ms
# Speed: 2.1ms preprocess, 362.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 706.3ms
# Speed: 1.9ms preprocess, 706.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 373.5ms
# Speed: 2.9ms preprocess, 373.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 650.0ms
# Speed: 2.1ms preprocess, 650.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 359.8ms
# Speed: 2.1ms preprocess, 359.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 698.5ms
# Speed: 2.3ms preprocess, 698.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 BL6MC, 1 BL18MC, 1 BLArc, 350.9ms
# Speed: 2.1ms preprocess, 350.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 661.5ms
# Speed: 2.2ms preprocess, 661.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BLArc, 345.4ms
# Speed: 2.2ms preprocess, 345.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 721.1ms
# Speed: 2.2ms preprocess, 721.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 360.3ms
# Speed: 2.0ms preprocess, 360.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 647.8ms
# Speed: 2.0ms preprocess, 647.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 362.8ms
# Speed: 2.1ms preprocess, 362.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 698.3ms
# Speed: 2.1ms preprocess, 698.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 378.3ms
# Speed: 2.5ms preprocess, 378.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 653.8ms
# Speed: 2.4ms preprocess, 653.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 358.1ms
# Speed: 2.3ms preprocess, 358.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 713.2ms
# Speed: 2.3ms preprocess, 713.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 344.4ms
# Speed: 2.1ms preprocess, 344.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 663.2ms
# Speed: 2.4ms preprocess, 663.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 343.3ms
# Speed: 2.2ms preprocess, 343.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 710.6ms
# Speed: 2.6ms preprocess, 710.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 359.2ms
# Speed: 2.1ms preprocess, 359.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 665.4ms
# Speed: 2.1ms preprocess, 665.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 340.5ms
# Speed: 2.2ms preprocess, 340.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 695.9ms
# Speed: 2.1ms preprocess, 695.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 361.5ms
# Speed: 3.0ms preprocess, 361.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 653.9ms
# Speed: 2.9ms preprocess, 653.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 351.1ms
# Speed: 2.0ms preprocess, 351.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 668.7ms
# Speed: 2.9ms preprocess, 668.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 384.7ms
# Speed: 2.7ms preprocess, 384.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 672.9ms
# Speed: 2.4ms preprocess, 672.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 344.4ms
# Speed: 2.2ms preprocess, 344.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 681.8ms
# Speed: 2.0ms preprocess, 681.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 355.9ms
# Speed: 2.5ms preprocess, 355.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 648.6ms
# Speed: 2.4ms preprocess, 648.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 338.0ms
# Speed: 2.9ms preprocess, 338.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 690.1ms
# Speed: 2.2ms preprocess, 690.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 356.5ms
# Speed: 2.3ms preprocess, 356.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 643.0ms
# Speed: 3.9ms preprocess, 643.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 349.3ms
# Speed: 2.2ms preprocess, 349.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 674.3ms
# Speed: 2.3ms preprocess, 674.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 391.6ms
# Speed: 2.2ms preprocess, 391.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 648.8ms
# Speed: 2.3ms preprocess, 648.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TR18ML, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 363.1ms
# Speed: 2.2ms preprocess, 363.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 661.6ms
# Speed: 2.0ms preprocess, 661.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TR18ML, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 450.3ms
# Speed: 2.1ms preprocess, 450.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 665.6ms
# Speed: 1.9ms preprocess, 665.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TR18ML, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 353.2ms
# Speed: 3.0ms preprocess, 353.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 654.3ms
# Speed: 2.1ms preprocess, 654.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 401.5ms
# Speed: 3.3ms preprocess, 401.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 665.2ms
# Speed: 2.1ms preprocess, 665.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 353.2ms
# Speed: 2.2ms preprocess, 353.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 652.3ms
# Speed: 2.6ms preprocess, 652.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 402.8ms
# Speed: 2.0ms preprocess, 402.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 656.6ms
# Speed: 2.7ms preprocess, 656.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 354.2ms
# Speed: 63.0ms preprocess, 354.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 651.9ms
# Speed: 2.1ms preprocess, 651.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 391.3ms
# Speed: 2.1ms preprocess, 391.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 639.8ms
# Speed: 2.1ms preprocess, 639.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 344.2ms
# Speed: 2.1ms preprocess, 344.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 667.9ms
# Speed: 2.1ms preprocess, 667.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 393.0ms
# Speed: 1.9ms preprocess, 393.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 641.2ms
# Speed: 2.3ms preprocess, 641.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 350.6ms
# Speed: 2.8ms preprocess, 350.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 646.9ms
# Speed: 2.4ms preprocess, 646.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 395.0ms
# Speed: 2.0ms preprocess, 395.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 661.5ms
# Speed: 2.9ms preprocess, 661.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 370.5ms
# Speed: 4.1ms preprocess, 370.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 683.2ms
# Speed: 2.2ms preprocess, 683.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 570.5ms
# Speed: 2.6ms preprocess, 570.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 658.4ms
# Speed: 2.0ms preprocess, 658.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 364.9ms
# Speed: 2.1ms preprocess, 364.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 669.5ms
# Speed: 3.3ms preprocess, 669.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 401.8ms
# Speed: 1.9ms preprocess, 401.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 678.1ms
# Speed: 2.0ms preprocess, 678.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 354.5ms
# Speed: 2.0ms preprocess, 354.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 661.7ms
# Speed: 2.9ms preprocess, 661.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 395.3ms
# Speed: 2.4ms preprocess, 395.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 655.3ms
# Speed: 2.0ms preprocess, 655.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 353.4ms
# Speed: 1.9ms preprocess, 353.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 662.4ms
# Speed: 2.8ms preprocess, 662.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 389.4ms
# Speed: 3.0ms preprocess, 389.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 672.5ms
# Speed: 2.1ms preprocess, 672.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 361.2ms
# Speed: 2.1ms preprocess, 361.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 670.6ms
# Speed: 2.2ms preprocess, 670.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 413.5ms
# Speed: 2.0ms preprocess, 413.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 580.5ms
# Speed: 2.0ms preprocess, 580.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 352.8ms
# Speed: 2.1ms preprocess, 352.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 1305.6ms
# Speed: 2.2ms preprocess, 1305.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 481.5ms
# Speed: 3.8ms preprocess, 481.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 830.8ms
# Speed: 2.1ms preprocess, 830.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 386.7ms
# Speed: 1.9ms preprocess, 386.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 1331.1ms
# Speed: 2.0ms preprocess, 1331.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 568.0ms
# Speed: 3.8ms preprocess, 568.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 890.3ms
# Speed: 2.4ms preprocess, 890.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 463.6ms
# Speed: 3.1ms preprocess, 463.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 750.3ms
# Speed: 2.0ms preprocess, 750.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 476.0ms
# Speed: 2.4ms preprocess, 476.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 879.3ms
# Speed: 2.8ms preprocess, 879.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 480.2ms
# Speed: 2.2ms preprocess, 480.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 820.9ms
# Speed: 2.6ms preprocess, 820.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TL6MC, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 BL18MC, 1 BRArc, 1 BLArc, 639.8ms
# Speed: 2.8ms preprocess, 639.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1 ball, 1241.3ms
# Speed: 2.3ms preprocess, 1241.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 424.0ms
# Speed: 3.1ms preprocess, 424.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 1267.9ms
# Speed: 2.3ms preprocess, 1267.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 393.9ms
# Speed: 2.3ms preprocess, 393.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 833.5ms
# Speed: 2.3ms preprocess, 833.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 449.2ms
# Speed: 1.9ms preprocess, 449.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 727.1ms
# Speed: 2.3ms preprocess, 727.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 367.3ms
# Speed: 2.1ms preprocess, 367.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 892.7ms
# Speed: 3.5ms preprocess, 892.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 408.3ms
# Speed: 3.7ms preprocess, 408.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 725.8ms
# Speed: 2.4ms preprocess, 725.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 379.3ms
# Speed: 2.0ms preprocess, 379.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 1 ball, 741.6ms
# Speed: 2.0ms preprocess, 741.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 BL18MC, 1 BRArc, 1 BLArc, 364.3ms
# Speed: 2.2ms preprocess, 364.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 667.9ms
# Speed: 2.0ms preprocess, 667.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 376.5ms
# Speed: 2.4ms preprocess, 376.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 728.8ms
# Speed: 2.5ms preprocess, 728.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 BL18MC, 1 BRArc, 1 BLArc, 389.6ms
# Speed: 2.0ms preprocess, 389.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 ball, 764.3ms
# Speed: 2.0ms preprocess, 764.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 BL18MC, 1 BRArc, 1 BLArc, 444.1ms
# Speed: 2.0ms preprocess, 444.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 ball, 833.2ms
# Speed: 2.1ms preprocess, 833.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 BL18MC, 1 BRArc, 1 BLArc, 429.6ms
# Speed: 2.3ms preprocess, 429.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 725.9ms
# Speed: 2.6ms preprocess, 725.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LMC, 1 LML, 1 BL18MC, 1 BRArc, 1 BLArc, 408.5ms
# Speed: 2.2ms preprocess, 408.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 800.5ms
# Speed: 2.6ms preprocess, 800.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 RMC, 1 BL18MC, 1 BRArc, 1 BLArc, 365.6ms
# Speed: 2.7ms preprocess, 365.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 677.9ms
# Speed: 2.2ms preprocess, 677.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 379.4ms
# Speed: 2.1ms preprocess, 379.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 ball, 691.3ms
# Speed: 3.4ms preprocess, 691.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 363.9ms
# Speed: 2.2ms preprocess, 363.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 ball, 666.6ms
# Speed: 1.9ms preprocess, 666.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 362.7ms
# Speed: 2.0ms preprocess, 362.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 ball, 719.7ms
# Speed: 2.2ms preprocess, 719.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 359.3ms
# Speed: 2.1ms preprocess, 359.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 ball, 820.5ms
# Speed: 2.1ms preprocess, 820.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TRArc, 1 TLArc, 1 RMC, 1 BL18MC, 1 BLArc, 362.0ms
# Speed: 2.3ms preprocess, 362.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 ball, 687.7ms
# Speed: 2.2ms preprocess, 687.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 373.4ms
# Speed: 2.1ms preprocess, 373.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1 ball, 658.4ms
# Speed: 2.1ms preprocess, 658.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 365.5ms
# Speed: 2.5ms preprocess, 365.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 681.2ms
# Speed: 2.6ms preprocess, 681.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 BL18MC, 1 BLArc, 360.9ms
# Speed: 1.9ms preprocess, 360.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 654.7ms
# Speed: 2.1ms preprocess, 654.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 355.5ms
# Speed: 2.0ms preprocess, 355.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 700.8ms
# Speed: 2.0ms preprocess, 700.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 364.3ms
# Speed: 2.7ms preprocess, 364.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 654.6ms
# Speed: 2.1ms preprocess, 654.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 BL18MC, 1 BLArc, 350.3ms
# Speed: 1.9ms preprocess, 350.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 708.9ms
# Speed: 2.1ms preprocess, 708.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 RMC, 1 LML, 1 BL18MC, 1 BLArc, 351.6ms
# Speed: 2.4ms preprocess, 351.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 685.1ms
# Speed: 2.8ms preprocess, 685.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 LML, 1 BL18MC, 1 BLArc, 377.3ms
# Speed: 2.4ms preprocess, 377.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 772.9ms
# Speed: 3.3ms preprocess, 772.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LML, 1 BL18MC, 1 BLArc, 361.2ms
# Speed: 2.2ms preprocess, 361.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 693.7ms
# Speed: 2.4ms preprocess, 693.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LML, 1 BL18MC, 1 BLArc, 386.0ms
# Speed: 2.1ms preprocess, 386.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 751.0ms
# Speed: 6.2ms preprocess, 751.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LML, 1 BL18MC, 1 BLArc, 386.2ms
# Speed: 3.1ms preprocess, 386.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 694.2ms
# Speed: 2.2ms preprocess, 694.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 LMC, 1 LML, 1 BL18MC, 1 BLArc, 379.0ms
# Speed: 2.2ms preprocess, 379.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 776.3ms
# Speed: 2.2ms preprocess, 776.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TR6ML, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LMC, 1 LML, 1 BL18MC, 1 BLArc, 467.8ms
# Speed: 3.1ms preprocess, 467.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 669.8ms
# Speed: 2.1ms preprocess, 669.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 BL18MC, 1 BLArc, 400.2ms
# Speed: 2.5ms preprocess, 400.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 658.9ms
# Speed: 2.2ms preprocess, 658.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 TLC, 1 TR6MC, 1 TL6MC, 1 TL6ML, 1 TL18MC, 1 TL18ML, 1 TRArc, 1 TLArc, 1 LML, 1 BL18MC, 1 BLArc, 381.7ms
# Speed: 2.1ms preprocess, 381.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 684.9ms
# ...
#
# 0: 384x640 17 players, 1 referee, 725.5ms
# Speed: 2.2ms preprocess, 725.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 383.8ms
# Speed: 2.2ms preprocess, 383.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 815.4ms
# Speed: 2.3ms preprocess, 815.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 399.0ms
# Speed: 2.6ms preprocess, 399.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 698.5ms
# Speed: 2.2ms preprocess, 698.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 469.7ms
# Speed: 2.4ms preprocess, 469.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 775.8ms
# Speed: 2.2ms preprocess, 775.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 404.4ms
# Speed: 2.3ms preprocess, 404.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 691.7ms
# Speed: 2.0ms preprocess, 691.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 385.4ms
# Speed: 2.8ms preprocess, 385.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 762.5ms
# Speed: 2.4ms preprocess, 762.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 426.5ms
# Speed: 2.2ms preprocess, 426.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 904.8ms
# Speed: 9.9ms preprocess, 904.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 894.8ms
# Speed: 64.5ms preprocess, 894.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1007.0ms
# Speed: 3.3ms preprocess, 1007.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 473.3ms
# Speed: 2.1ms preprocess, 473.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 897.1ms
# Speed: 3.4ms preprocess, 897.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 1193.5ms
# Speed: 2.2ms preprocess, 1193.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1020.1ms
# Speed: 42.0ms preprocess, 1020.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 409.8ms
# Speed: 2.2ms preprocess, 409.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 748.6ms
# Speed: 2.2ms preprocess, 748.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 566.9ms
# Speed: 4.1ms preprocess, 566.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 796.4ms
# Speed: 3.3ms preprocess, 796.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 396.9ms
# Speed: 2.6ms preprocess, 396.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 739.2ms
# Speed: 2.4ms preprocess, 739.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 412.8ms
# Speed: 2.1ms preprocess, 412.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 817.0ms
# Speed: 2.8ms preprocess, 817.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 399.6ms
# Speed: 2.4ms preprocess, 399.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1250.7ms
# Speed: 2.0ms preprocess, 1250.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 595.4ms
# Speed: 2.3ms preprocess, 595.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 747.2ms
# Speed: 2.9ms preprocess, 747.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 391.4ms
# Speed: 3.2ms preprocess, 391.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 836.0ms
# Speed: 40.3ms preprocess, 836.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 379.6ms
# Speed: 2.3ms preprocess, 379.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 858.0ms
# Speed: 2.5ms preprocess, 858.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 402.9ms
# Speed: 2.4ms preprocess, 402.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 747.9ms
# Speed: 2.4ms preprocess, 747.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 383.8ms
# Speed: 2.1ms preprocess, 383.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 716.2ms
# Speed: 2.0ms preprocess, 716.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 426.9ms
# Speed: 4.1ms preprocess, 426.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 741.1ms
# Speed: 2.4ms preprocess, 741.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 548.8ms
# Speed: 2.5ms preprocess, 548.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 723.7ms
# Speed: 2.2ms preprocess, 723.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 462.0ms
# Speed: 2.3ms preprocess, 462.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 726.8ms
# Speed: 2.3ms preprocess, 726.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 378.0ms
# Speed: 2.4ms preprocess, 378.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 753.4ms
# Speed: 2.1ms preprocess, 753.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 404.5ms
# Speed: 2.5ms preprocess, 404.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 939.8ms
# Speed: 2.3ms preprocess, 939.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 388.7ms
# Speed: 1.9ms preprocess, 388.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1293.7ms
# Speed: 2.5ms preprocess, 1293.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 441.3ms
# Speed: 3.1ms preprocess, 441.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 821.1ms
# Speed: 2.5ms preprocess, 821.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 444.1ms
# Speed: 3.5ms preprocess, 444.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 722.2ms
# Speed: 2.6ms preprocess, 722.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 407.7ms
# Speed: 2.4ms preprocess, 407.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 946.3ms
# Speed: 2.2ms preprocess, 946.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 394.7ms
# Speed: 3.7ms preprocess, 394.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 728.4ms
# Speed: 2.1ms preprocess, 728.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 395.8ms
# Speed: 2.2ms preprocess, 395.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 799.3ms
# Speed: 2.1ms preprocess, 799.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 384.2ms
# Speed: 2.7ms preprocess, 384.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 711.3ms
# Speed: 2.0ms preprocess, 711.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 412.5ms
# Speed: 2.7ms preprocess, 412.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 939.5ms
# Speed: 1.9ms preprocess, 939.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 392.9ms
# Speed: 2.1ms preprocess, 392.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 743.3ms
# Speed: 2.2ms preprocess, 743.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 422.5ms
# Speed: 2.2ms preprocess, 422.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 898.2ms
# Speed: 4.2ms preprocess, 898.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 409.1ms
# Speed: 2.1ms preprocess, 409.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 715.5ms
# Speed: 2.3ms preprocess, 715.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 455.4ms
# Speed: 2.4ms preprocess, 455.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 722.5ms
# Speed: 2.3ms preprocess, 722.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 467.6ms
# Speed: 2.4ms preprocess, 467.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 760.6ms
# Speed: 1.8ms preprocess, 760.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 384.5ms
# Speed: 2.6ms preprocess, 384.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 722.1ms
# Speed: 3.0ms preprocess, 722.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 393.6ms
# Speed: 2.0ms preprocess, 393.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 759.8ms
# Speed: 2.0ms preprocess, 759.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 381.7ms
# Speed: 2.3ms preprocess, 381.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 830.8ms
# Speed: 2.0ms preprocess, 830.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 394.1ms
# Speed: 2.1ms preprocess, 394.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 756.1ms
# Speed: 2.5ms preprocess, 756.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 398.4ms
# Speed: 2.0ms preprocess, 398.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 713.4ms
# Speed: 2.1ms preprocess, 713.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 393.5ms
# Speed: 2.2ms preprocess, 393.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 777.8ms
# Speed: 2.1ms preprocess, 777.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 381.3ms
# Speed: 2.0ms preprocess, 381.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 742.6ms
# Speed: 27.2ms preprocess, 742.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 386.5ms
# Speed: 1.9ms preprocess, 386.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 762.2ms
# Speed: 2.3ms preprocess, 762.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 390.4ms
# Speed: 2.7ms preprocess, 390.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 735.9ms
# Speed: 2.0ms preprocess, 735.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 391.8ms
# Speed: 2.3ms preprocess, 391.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 781.5ms
# Speed: 2.4ms preprocess, 781.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 386.6ms
# Speed: 2.6ms preprocess, 386.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 727.3ms
# Speed: 2.4ms preprocess, 727.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 395.8ms
# Speed: 2.2ms preprocess, 395.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 926.2ms
# Speed: 2.6ms preprocess, 926.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 RMC, 1 LMC, 1 BR6MC, 1 BL6MC, 1 BR6ML, 1 BL6ML, 1 BRArc, 396.0ms
# Speed: 2.8ms preprocess, 396.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
